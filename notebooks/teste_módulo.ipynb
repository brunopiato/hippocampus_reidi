# %% [markdown]
# # Library imports

# %%
# Valdiates if the current working directory is inside notebooks and changes it to the parent directory if it is. This is useful for running the notebook from the correct directory.
import os
if os.getcwd().endswith("notebooks"):
    os.chdir("..")
root_path = os.getcwd()

import src
print(src.__version__)
print(src.__name__)
print(src.__author__)
# Out:
# 0.1.0
# _Hippocampus reidi_
# Bruno Garcia Piato

# %%
image_path = f"{root_path}/data/img/imagem6.jpg"
color_names = ('green', 'red', 'blue')
color_ranges = ([[0, 100, 0], [100, 255, 100]],
                [[100, 0, 0], [255, 100, 100]],
                [[204, 204, 255], [0, 35, 102]])

# %% [markdown]
# # Teste com funções

# %%
# %matplotlib widget
colors = src.pick_color_from_image_matplotlib(image_path=image_path)
# Out:
# Button(button_style='success', description='Finalizar seleção', style=ButtonStyle())
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
colors
# Out:
# [[37, 18, 3], [226, 94, 22], [42, 52, 0], [38, 59, 0]]

# %%
resultados = src.calculate_color_percentage(image_path=f"{root_path}/data/img/imagem6.jpg", 
                                            color_names=['verde', 'vermelho', 'azul'], 
                                            color_ranges=[[colors[0], colors[1]], 
                                                            [colors[2], colors[3]], 
                                                            [[0, 35, 102], [204, 204, 255]]])
# Out:
# The verde percentage is 25.543%.
# The vermelho percentage is 0.0%.
# The azul percentage is 0.0%.
# The image percentage is 68.366%.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
resultados
# Out:
# {'verde': {'lower': array([37, 18,  3]),
#   'upper': array([226,  94,  22]),
#   'pixels': 137427,
#   'percentage': 0.2554258026024523},
#  'vermelho': {'lower': array([42, 52,  0]),
#   'upper': array([38, 59,  0]),
#   'pixels': 0,
#   'percentage': 0.0},
#  'azul': {'lower': array([  0,  35, 102]),
#   'upper': array([204, 204, 255]),
#   'pixels': 0,
#   'percentage': 0.0},
#  'image': {'lower': array([0, 0, 0]),
#   'upper': array([0, 0, 0]),
#   'pixels': 1162769,
#   'percentage': 0.6836600423330198}}

# %% [markdown]
# # Teste com varredura de pasta

# %%
folder_path = f"{root_path}/data/img"
color_names = ('green', 'red', 'blue')
color_ranges = ([[0, 100, 0], [100, 255, 100]],
                [[100, 0, 0], [255, 100, 100]],
                [[204, 204, 255], [0, 35, 102]])

src.process_images_in_folder(folder_path, color_names, color_ranges)
# Out:
# imagem1_full.jpg
# The green percentage is 13.08%.
# The red percentage is 0.425%.
# The blue percentage is 0.0%.
# The image percentage is 0.0%.
# imagem2_full.jpg
# The green percentage is 3.621%.
# The red percentage is 2.801%.
# The blue percentage is 0.0%.
# The image percentage is 0.0%.
# imagem3_full.jpg
# The green percentage is 5.297%.
# The red percentage is 0.222%.
# The blue percentage is 0.0%.
# The image percentage is 0.0%.
# imagem4.jpg
# The green percentage is 5.803%.
# The red percentage is 8.813%.
# The blue percentage is 0.0%.
# The image percentage is 74.093%.
# imagem5.jpg
# The green percentage is 13.044%.
# The red percentage is 1.006%.
# The blue percentage is 0.0%.
# The image percentage is 73.631%.
# imagem6.jpg
# The green percentage is 0.445%.
# The red percentage is 8.912%.
# The blue percentage is 0.0%.
# The image percentage is 68.366%.
# imagem7.jpg
# The green percentage is 25.327%.
# The red percentage is 8.342%.
# The blue percentage is 0.0%.
# ...
